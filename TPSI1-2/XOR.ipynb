# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
print(tf.version.VERSION)
# Out:
# 2.0.0

# %%
# The input and output, i.e. truth table, of a XOR gate
x_train = np.array([[0,0],[0,1],[1,0],[1,1]], "uint8")
y_train = np.array([[0],[1],[1],[0]], "uint8")

# Create neural networks model
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(2, )))
model.add(Dense(1, activation='sigmoid'))

sgd = tf.keras.optimizers.SGD(learning_rate=0.1)

model.compile(loss='binary_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                96
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 129
# Trainable params: 129
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size = 4, epochs = 100, verbose = 2)
# Out:
# Train on 4 samples
# Epoch 1/100
# 4/4 - 1s - loss: 0.6727 - accuracy: 0.7500
# Epoch 2/100
# 4/4 - 0s - loss: 0.6690 - accuracy: 0.7500
# Epoch 3/100
# 4/4 - 0s - loss: 0.6648 - accuracy: 0.7500
# Epoch 4/100
# 4/4 - 0s - loss: 0.6609 - accuracy: 0.7500
# Epoch 5/100
# 4/4 - 0s - loss: 0.6572 - accuracy: 0.7500
# Epoch 6/100
# 4/4 - 0s - loss: 0.6537 - accuracy: 0.7500
# Epoch 7/100
# 4/4 - 0s - loss: 0.6504 - accuracy: 0.7500
# Epoch 8/100
# 4/4 - 0s - loss: 0.6475 - accuracy: 0.7500
# Epoch 9/100
# 4/4 - 0s - loss: 0.6444 - accuracy: 0.7500
# Epoch 10/100
# 4/4 - 0s - loss: 0.6417 - accuracy: 0.7500
# Epoch 11/100
# 4/4 - 0s - loss: 0.6388 - accuracy: 0.7500
# Epoch 12/100
# 4/4 - 0s - loss: 0.6360 - accuracy: 0.7500
# Epoch 13/100
# 4/4 - 0s - loss: 0.6335 - accuracy: 0.7500
# Epoch 14/100
# 4/4 - 0s - loss: 0.6308 - accuracy: 0.7500
# Epoch 15/100
# 4/4 - 0s - loss: 0.6290 - accuracy: 0.7500
# Epoch 16/100
# 4/4 - 0s - loss: 0.6271 - accuracy: 0.7500
# Epoch 17/100
# 4/4 - 0s - loss: 0.6254 - accuracy: 0.7500
# Epoch 18/100
# 4/4 - 0s - loss: 0.6233 - accuracy: 0.7500
# Epoch 19/100
# 4/4 - 0s - loss: 0.6216 - accuracy: 0.7500
# Epoch 20/100
# 4/4 - 0s - loss: 0.6196 - accuracy: 1.0000
# Epoch 21/100
# 4/4 - 0s - loss: 0.6177 - accuracy: 1.0000
# Epoch 22/100
# 4/4 - 0s - loss: 0.6160 - accuracy: 1.0000
# Epoch 23/100
# 4/4 - 0s - loss: 0.6139 - accuracy: 1.0000
# Epoch 24/100
# 4/4 - 0s - loss: 0.6123 - accuracy: 1.0000
# Epoch 25/100
# 4/4 - 0s - loss: 0.6103 - accuracy: 1.0000
# Epoch 26/100
# 4/4 - 0s - loss: 0.6085 - accuracy: 1.0000
# Epoch 27/100
# 4/4 - 0s - loss: 0.6072 - accuracy: 1.0000
# Epoch 28/100
# 4/4 - 0s - loss: 0.6052 - accuracy: 1.0000
# Epoch 29/100
# 4/4 - 0s - loss: 0.6039 - accuracy: 1.0000
# Epoch 30/100
# 4/4 - 0s - loss: 0.6018 - accuracy: 1.0000
# Epoch 31/100
# 4/4 - 0s - loss: 0.6005 - accuracy: 1.0000
# Epoch 32/100
# 4/4 - 0s - loss: 0.5987 - accuracy: 1.0000
# Epoch 33/100
# 4/4 - 0s - loss: 0.5971 - accuracy: 1.0000
# Epoch 34/100
# 4/4 - 0s - loss: 0.5956 - accuracy: 1.0000
# Epoch 35/100
# 4/4 - 0s - loss: 0.5936 - accuracy: 1.0000
# Epoch 36/100
# 4/4 - 0s - loss: 0.5920 - accuracy: 1.0000
# Epoch 37/100
# 4/4 - 0s - loss: 0.5902 - accuracy: 1.0000
# Epoch 38/100
# 4/4 - 0s - loss: 0.5885 - accuracy: 1.0000
# Epoch 39/100
# 4/4 - 0s - loss: 0.5870 - accuracy: 1.0000
# Epoch 40/100
# 4/4 - 0s - loss: 0.5849 - accuracy: 1.0000
# Epoch 41/100
# 4/4 - 0s - loss: 0.5832 - accuracy: 1.0000
# Epoch 42/100
# 4/4 - 0s - loss: 0.5815 - accuracy: 1.0000
# Epoch 43/100
# 4/4 - 0s - loss: 0.5795 - accuracy: 1.0000
# Epoch 44/100
# 4/4 - 0s - loss: 0.5781 - accuracy: 1.0000
# Epoch 45/100
# 4/4 - 0s - loss: 0.5757 - accuracy: 1.0000
# Epoch 46/100
# 4/4 - 0s - loss: 0.5742 - accuracy: 1.0000
# Epoch 47/100
# 4/4 - 0s - loss: 0.5723 - accuracy: 1.0000
# Epoch 48/100
# 4/4 - 0s - loss: 0.5704 - accuracy: 1.0000
# Epoch 49/100
# 4/4 - 0s - loss: 0.5687 - accuracy: 1.0000
# Epoch 50/100
# 4/4 - 0s - loss: 0.5665 - accuracy: 1.0000
# Epoch 51/100
# 4/4 - 0s - loss: 0.5645 - accuracy: 1.0000
# Epoch 52/100
# 4/4 - 0s - loss: 0.5633 - accuracy: 1.0000
# Epoch 53/100
# 4/4 - 0s - loss: 0.5606 - accuracy: 1.0000
# Epoch 54/100
# 4/4 - 0s - loss: 0.5592 - accuracy: 1.0000
# Epoch 55/100
# 4/4 - 0s - loss: 0.5573 - accuracy: 1.0000
# Epoch 56/100
# 4/4 - 0s - loss: 0.5545 - accuracy: 1.0000
# Epoch 57/100
# 4/4 - 0s - loss: 0.5532 - accuracy: 1.0000
# Epoch 58/100
# 4/4 - 0s - loss: 0.5511 - accuracy: 1.0000
# Epoch 59/100
# 4/4 - 0s - loss: 0.5491 - accuracy: 1.0000
# Epoch 60/100
# 4/4 - 0s - loss: 0.5471 - accuracy: 1.0000
# Epoch 61/100
# 4/4 - 0s - loss: 0.5450 - accuracy: 1.0000
# Epoch 62/100
# 4/4 - 0s - loss: 0.5435 - accuracy: 1.0000
# Epoch 63/100
# 4/4 - 0s - loss: 0.5409 - accuracy: 1.0000
# Epoch 64/100
# 4/4 - 0s - loss: 0.5389 - accuracy: 1.0000
# Epoch 65/100
# 4/4 - 0s - loss: 0.5375 - accuracy: 1.0000
# Epoch 66/100
# 4/4 - 0s - loss: 0.5349 - accuracy: 1.0000
# Epoch 67/100
# 4/4 - 0s - loss: 0.5332 - accuracy: 1.0000
# Epoch 68/100
# 4/4 - 0s - loss: 0.5310 - accuracy: 1.0000
# Epoch 69/100
# 4/4 - 0s - loss: 0.5289 - accuracy: 1.0000
# Epoch 70/100
# 4/4 - 0s - loss: 0.5274 - accuracy: 1.0000
# Epoch 71/100
# 4/4 - 0s - loss: 0.5251 - accuracy: 1.0000
# Epoch 72/100
# 4/4 - 0s - loss: 0.5228 - accuracy: 1.0000
# Epoch 73/100
# 4/4 - 0s - loss: 0.5214 - accuracy: 1.0000
# Epoch 74/100
# 4/4 - 0s - loss: 0.5189 - accuracy: 1.0000
# Epoch 75/100
# 4/4 - 0s - loss: 0.5168 - accuracy: 1.0000
# Epoch 76/100
# 4/4 - 0s - loss: 0.5150 - accuracy: 1.0000
# Epoch 77/100
# 4/4 - 0s - loss: 0.5126 - accuracy: 1.0000
# Epoch 78/100
# 4/4 - 0s - loss: 0.5110 - accuracy: 1.0000
# Epoch 79/100
# 4/4 - 0s - loss: 0.5085 - accuracy: 1.0000
# Epoch 80/100
# 4/4 - 0s - loss: 0.5061 - accuracy: 1.0000
# Epoch 81/100
# 4/4 - 0s - loss: 0.5046 - accuracy: 1.0000
# Epoch 82/100
# 4/4 - 0s - loss: 0.5020 - accuracy: 1.0000
# Epoch 83/100
# 4/4 - 0s - loss: 0.5001 - accuracy: 1.0000
# Epoch 84/100
# 4/4 - 0s - loss: 0.4978 - accuracy: 1.0000
# Epoch 85/100
# 4/4 - 0s - loss: 0.4957 - accuracy: 1.0000
# Epoch 86/100
# 4/4 - 0s - loss: 0.4942 - accuracy: 1.0000
# Epoch 87/100
# 4/4 - 0s - loss: 0.4914 - accuracy: 1.0000
# Epoch 88/100
# 4/4 - 0s - loss: 0.4891 - accuracy: 1.0000
# Epoch 89/100
# 4/4 - 0s - loss: 0.4878 - accuracy: 1.0000
# Epoch 90/100
# 4/4 - 0s - loss: 0.4846 - accuracy: 1.0000
# Epoch 91/100
# 4/4 - 0s - loss: 0.4832 - accuracy: 1.0000
# Epoch 92/100
# 4/4 - 0s - loss: 0.4811 - accuracy: 1.0000
# Epoch 93/100
# 4/4 - 0s - loss: 0.4781 - accuracy: 1.0000
# Epoch 94/100
# 4/4 - 0s - loss: 0.4766 - accuracy: 1.0000
# Epoch 95/100
# 4/4 - 0s - loss: 0.4745 - accuracy: 1.0000
# Epoch 96/100
# 4/4 - 0s - loss: 0.4717 - accuracy: 1.0000
# Epoch 97/100
# 4/4 - 0s - loss: 0.4702 - accuracy: 1.0000
# Epoch 98/100
# 4/4 - 0s - loss: 0.4686 - accuracy: 1.0000
# Epoch 99/100
# 4/4 - 0s - loss: 0.4650 - accuracy: 1.0000
# Epoch 100/100
# 4/4 - 0s - loss: 0.4641 - accuracy: 1.0000

# %%
print('Evaluate Model')
pred_val = model.predict(x_train)
print(pred_val)
print('Round the values')
print(pred_val.round())
# Out:
# Evaluate Model
# [[0.41292393]
#  [0.73875266]
#  [0.5738235 ]
#  [0.36726937]]
# Round the values
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
